# %%
import pandas as pd
import numpy as np
from keras.layers import (Convolution2D, GlobalAveragePooling2D, BatchNormalization, Flatten,
                          GlobalMaxPool2D, MaxPool2D, concatenate, Activation)
from keras.utils import Sequence, to_categorical
from keras import backend as K

from sklearn.model_selection import StratifiedKFold

import librosa

# %%
# Change this to True for full dataset and learning
COMPLETE_RUN = False
data_path = '../data'

# %%
train = pd.read_csv(data_path + "/train_noisy.csv")
test = pd.read_csv(data_path + "/sample_submission.csv")

# %%
train.sample(5)
# Out:
#               fname                                             labels
# 12350  9e8f1ef2.wav                                     Gurgling,Knock
# 8900   72c27963.wav                                            Writing
# 2074   1ad384fe.wav  Fill_(with_liquid),Water_tap_and_faucet,Drip,S...
# 962    0c4aed26.wav                                           Cheering
# 11429  9357b956.wav                        Chirp_and_tweet,Church_bell

# %%
print("Number of train examples=", train.shape[0], "  Number of classes=", len(set(train['labels'])))
print("Number of test examples=", test.shape[0], "  Number of classes=", len(set(test.columns[1:])))
# Out:
# Number of train examples= 19815   Number of classes= 1168
# Number of test examples= 1120   Number of classes= 80

# %%
test.columns
# Out:
# Index(['fname', 'Accelerating_and_revving_and_vroom', 'Accordion',
#        'Acoustic_guitar', 'Applause', 'Bark', 'Bass_drum', 'Bass_guitar',
#        'Bathtub_(filling_or_washing)', 'Bicycle_bell',
#        'Burping_and_eructation', 'Bus', 'Buzz', 'Car_passing_by', 'Cheering',
#        'Chewing_and_mastication', 'Child_speech_and_kid_speaking',
#        'Chink_and_clink', 'Chirp_and_tweet', 'Church_bell', 'Clapping',
#        'Computer_keyboard', 'Crackle', 'Cricket', 'Crowd',
#        'Cupboard_open_or_close', 'Cutlery_and_silverware',
#        'Dishes_and_pots_and_pans', 'Drawer_open_or_close', 'Drip',
#        'Electric_guitar', 'Fart', 'Female_singing',
#        'Female_speech_and_woman_speaking', 'Fill_(with_liquid)',
#        'Finger_snapping', 'Frying_(food)', 'Gasp', 'Glockenspiel', 'Gong',
#        'Gurgling', 'Harmonica', 'Hi-hat', 'Hiss', 'Keys_jangling', 'Knock',
#        'Male_singing', 'Male_speech_and_man_speaking', 'Marimba_and_xylophone',
#        'Mechanical_fan', 'Meow', 'Microwave_oven', 'Motorcycle', 'Printer',
#        'Purr', 'Race_car_and_auto_racing', 'Raindrop', 'Run', 'Scissors',
#        'Screaming', 'Shatter', 'Sigh', 'Sink_(filling_or_washing)',
#        'Skateboard', 'Slam', 'Sneeze', 'Squeak', 'Stream', 'Strum', 'Tap',
#        'Tick-tock', 'Toilet_flush', 'Traffic_noise_and_roadway_noise',
#        'Trickle_and_dribble', 'Walk_and_footsteps', 'Water_tap_and_faucet',
#        'Waves_and_surf', 'Whispering', 'Writing', 'Yell', 'Zipper_(clothing)'],
#       dtype='object')

# %%
np.set_printoptions(threshold=1168)
train['labels'].unique()
# Out:
# array(['Bathtub_(filling_or_washing)', 'Motorcycle',
#        'Marimba_and_xylophone,Glockenspiel',
#        'Water_tap_and_faucet,Sink_(filling_or_washing)', 'Raindrop',
#        'Bass_guitar', 'Raindrop,Trickle_and_dribble',
#        'Strum,Acoustic_guitar', 'Bass_drum,Hi-hat', 'Harmonica', 'Slam',
#        'Scissors', 'Cheering,Crowd', 'Crackle', 'Purr', 'Crowd', 'Yell',
#        'Female_singing', 'Printer', 'Finger_snapping', 'Microwave_oven',
#        'Hi-hat', 'Run', 'Bass_drum', 'Squeak', 'Acoustic_guitar',
#        'Male_speech_and_man_speaking', 'Tap', 'Microwave_oven,Buzz',
#        'Water_tap_and_faucet,Frying_(food)', 'Fart',
#        'Race_car_and_auto_racing', 'Frying_(food)',
#        'Motorcycle,Microwave_oven', 'Walk_and_footsteps', 'Buzz',
#        'Accelerating_and_revving_and_vroom', 'Stream', 'Male_singing',
#        'Chirp_and_tweet', 'Clapping', 'Mechanical_fan',
#        'Frying_(food),Dishes_and_pots_and_pans,Cutlery_and_silverware',
#        'Mechanical_fan,Buzz', 'Female_speech_and_woman_speaking',
#        'Cricket,Burping_and_eructation', 'Cupboard_open_or_close,Knock',
#        'Bicycle_bell,Chink_and_clink', 'Toilet_flush', 'Church_bell',
#        'Computer_keyboard',
#        'Dishes_and_pots_and_pans,Cutlery_and_silverware', 'Whispering',
#        'Zipper_(clothing),Writing', 'Keys_jangling', 'Meow', 'Bark',
#        'Screaming', 'Cupboard_open_or_close', 'Bus',
#        'Marimba_and_xylophone', 'Sneeze',
#        'Shatter,Computer_keyboard,Keys_jangling', 'Fill_(with_liquid)',
#        'Waves_and_surf', 'Traffic_noise_and_roadway_noise',
#        'Drawer_open_or_close',
#        'Bicycle_bell,Dishes_and_pots_and_pans,Cutlery_and_silverware,Chink_and_clink',
#        'Gasp,Sigh,Finger_snapping', 'Applause', 'Strum,Electric_guitar',
#        'Trickle_and_dribble', 'Chink_and_clink', 'Knock', 'Cricket',
#        'Gasp', 'Zipper_(clothing),Purr,Fart', 'Shatter',
#        'Squeak,Cupboard_open_or_close,Knock',
#        'Fill_(with_liquid),Computer_keyboard,Water_tap_and_faucet',
#        'Skateboard,Walk_and_footsteps', 'Zipper_(clothing),Sneeze',
#        'Zipper_(clothing)', 'Frying_(food),Hiss', 'Electric_guitar',
#        'Cupboard_open_or_close,Drawer_open_or_close', 'Gong',
#        'Chewing_and_mastication', 'Zipper_(clothing),Fart',
#        'Child_speech_and_kid_speaking', 'Sigh', 'Hiss', 'Car_passing_by',
#        'Accordion', 'Cutlery_and_silverware', 'Sigh,Slam',
#        'Bass_guitar,Gong', 'Cheering', 'Strum',
#        'Car_passing_by,Race_car_and_auto_racing',
#        'Run,Walk_and_footsteps', 'Burping_and_eructation', 'Skateboard',
#        'Tick-tock,Acoustic_guitar', 'Bathtub_(filling_or_washing),Drip',
#        'Tick-tock,Dishes_and_pots_and_pans', 'Stream,Trickle_and_dribble',
#        'Glockenspiel,Electric_guitar', 'Tick-tock', 'Gurgling', 'Drip',
#        'Knock,Slam', 'Bicycle_bell', 'Bicycle_bell,Knock',
#        'Burping_and_eructation,Toilet_flush', 'Writing', 'Strum,Yell',
#        'Zipper_(clothing),Fart,Finger_snapping,Scissors',
#        'Yell,Female_singing', 'Marimba_and_xylophone,Bass_guitar',
#        'Strum,Bass_guitar,Electric_guitar', 'Glockenspiel',
#        'Finger_snapping,Knock', 'Run,Crackle',
#        'Zipper_(clothing),Tap,Cupboard_open_or_close,Knock',
#        'Zipper_(clothing),Chewing_and_mastication',
#        'Walk_and_footsteps,Crackle',
#        'Marimba_and_xylophone,Glockenspiel,Applause',
#        'Bicycle_bell,Church_bell', 'Zipper_(clothing),Run,Crackle',
#        'Car_passing_by,Gong',
#        'Water_tap_and_faucet,Drip,Sink_(filling_or_washing)',
#        'Bathtub_(filling_or_washing),Child_speech_and_kid_speaking',
#        'Bark,Frying_(food)', 'Keys_jangling,Scissors',
#        'Mechanical_fan,Microwave_oven,Buzz',
#        'Fill_(with_liquid),Computer_keyboard', 'Gasp,Sigh',
#        'Glockenspiel,Church_bell', 'Purr,Walk_and_footsteps',
#        'Hi-hat,Church_bell', 'Strum,Yell,Electric_guitar',
#        'Skateboard,Slam',
#        'Water_tap_and_faucet,Trickle_and_dribble,Sink_(filling_or_washing)',
#        'Child_speech_and_kid_speaking,Burping_and_eructation',
#        'Shatter,Skateboard',
#        'Burping_and_eructation,Dishes_and_pots_and_pans,Cutlery_and_silverware',
#        'Fill_(with_liquid),Water_tap_and_faucet',
#        'Cupboard_open_or_close,Finger_snapping,Knock',
#        'Fill_(with_liquid),Chewing_and_mastication',
#        'Microwave_oven,Gong', 'Dishes_and_pots_and_pans',
#        'Sink_(filling_or_washing)', 'Church_bell,Gong',
#        'Dishes_and_pots_and_pans,Cutlery_and_silverware,Chink_and_clink',
#        'Drip,Chewing_and_mastication', 'Crackle,Scissors',
#        'Hi-hat,Bass_guitar', 'Writing,Finger_snapping',
#        'Race_car_and_auto_racing,Skateboard', 'Accordion,Hi-hat',
#        'Zipper_(clothing),Gasp', 'Squeak,Female_singing',
#        'Squeak,Burping_and_eructation', 'Mechanical_fan,Electric_guitar',
#        'Computer_keyboard,Microwave_oven',
#        'Fill_(with_liquid),Frying_(food)', 'Electric_guitar,Harmonica',
#        'Cricket,Chirp_and_tweet',
#        'Squeak,Tick-tock,Finger_snapping,Scissors',
#        'Bathtub_(filling_or_washing),Toilet_flush', 'Whispering,Scissors',
#        'Yell,Cheering', 'Drip,Trickle_and_dribble',
#        'Mechanical_fan,Stream', 'Writing,Burping_and_eructation',
#        'Finger_snapping,Female_singing',
#        'Child_speech_and_kid_speaking,Sneeze',
#        'Glockenspiel,Bicycle_bell', 'Bicycle_bell,Bass_guitar',
#        'Shatter,Keys_jangling', 'Bark,Buzz',
#        'Female_speech_and_woman_speaking,Male_speech_and_man_speaking',
#        'Tap,Clapping', 'Shatter,Printer',
#        'Bicycle_bell,Keys_jangling,Chink_and_clink', 'Fart,Sigh,Sneeze',
#        'Tick-tock,Church_bell', 'Gasp,Writing,Whispering,Finger_snapping',
#        'Bark,Burping_and_eructation',
#        'Fill_(with_liquid),Computer_keyboard,Drip,Chewing_and_mastication',
#        'Fill_(with_liquid),Drip',
#        'Car_passing_by,Motorcycle,Accelerating_and_revving_and_vroom',
#        'Bathtub_(filling_or_washing),Drawer_open_or_close',
#        'Fill_(with_liquid),Trickle_and_dribble',
#        'Gasp,Writing,Chewing_and_mastication,Scissors', 'Writing,Meow',
#        'Zipper_(clothing),Gasp,Chewing_and_mastication',
#        'Tap,Finger_snapping', 'Microwave_oven,Keys_jangling,Printer',
#        'Cupboard_open_or_close,Drawer_open_or_close,Slam',
#        'Bathtub_(filling_or_washing),Water_tap_and_faucet',
#        'Accordion,Harmonica', 'Finger_snapping,Clapping',
#        'Cupboard_open_or_close,Knock,Slam', 'Gasp,Raindrop,Sigh',
#        'Fill_(with_liquid),Chewing_and_mastication,Sink_(filling_or_washing)',
#        'Bicycle_bell,Raindrop', 'Hi-hat,Electric_guitar',
#        'Water_tap_and_faucet', 'Tick-tock,Chewing_and_mastication',
#        'Car_passing_by,Crowd',
#        'Water_tap_and_faucet,Frying_(food),Sink_(filling_or_washing)',
#        'Trickle_and_dribble,Chirp_and_tweet', 'Bicycle_bell,Gong',
#        'Shatter,Computer_keyboard', 'Fill_(with_liquid),Toilet_flush',
#        'Screaming,Sneeze', 'Frying_(food),Stream', 'Meow,Sneeze',
#        'Mechanical_fan,Motorcycle', 'Bicycle_bell,Screaming',
#        'Race_car_and_auto_racing,Accelerating_and_revving_and_vroom',
#        'Zipper_(clothing),Gasp,Fart,Burping_and_eructation,Sigh',
#        'Water_tap_and_faucet,Drip', 'Whispering,Tick-tock',
#        'Computer_keyboard,Drip,Sigh,Gurgling',
#        'Purr,Burping_and_eructation', 'Purr,Finger_snapping',
#        'Fill_(with_liquid),Drip,Gurgling,Toilet_flush,Sink_(filling_or_washing)',
#        'Raindrop,Crackle',
#        'Motorcycle,Accelerating_and_revving_and_vroom',
#        'Traffic_noise_and_roadway_noise,Crowd', 'Writing,Scissors',
#        'Writing,Fart,Finger_snapping', 'Squeak,Meow',
#        'Child_speech_and_kid_speaking,Sneeze,Scissors',
#        'Zipper_(clothing),Fart,Sneeze', 'Car_passing_by,Buzz',
#        'Zipper_(clothing),Walk_and_footsteps',
#        'Microwave_oven,Burping_and_eructation',
#        'Computer_keyboard,Finger_snapping', 'Keys_jangling,Printer',
#        'Fill_(with_liquid),Water_tap_and_faucet,Drip,Sink_(filling_or_washing)',
#        'Crackle,Knock,Buzz',
#        'Bicycle_bell,Traffic_noise_and_roadway_noise', 'Cricket,Buzz',
#        'Strum,Electric_guitar,Cheering', 'Frying_(food),Crackle',
#        'Glockenspiel,Hi-hat',
#        'Mechanical_fan,Keys_jangling,Chink_and_clink',
#        'Tick-tock,Church_bell,Gong',
#        'Gasp,Squeak,Sigh,Finger_snapping,Scissors',
#        'Microwave_oven,Church_bell,Gong',
#        'Fill_(with_liquid),Drip,Toilet_flush,Sink_(filling_or_washing)',
#        'Marimba_and_xylophone,Male_speech_and_man_speaking',
#        'Bus,Microwave_oven',
#        'Squeak,Fart,Chewing_and_mastication,Scissors',
#        'Child_speech_and_kid_speaking,Meow',
#        'Tick-tock,Burping_and_eructation',
#        'Burping_and_eructation,Sigh,Screaming',
#        'Dishes_and_pots_and_pans,Cutlery_and_silverware,Sneeze',
#        'Hi-hat,Acoustic_guitar,Harmonica',
#        'Microwave_oven,Cupboard_open_or_close', 'Gasp,Whispering,Sigh',
#        'Hiss,Toilet_flush',
#        'Cupboard_open_or_close,Hi-hat,Chink_and_clink',
#        'Fill_(with_liquid),Drip,Sink_(filling_or_washing)',
#        'Car_passing_by,Crackle',
#        'Child_speech_and_kid_speaking,Cupboard_open_or_close,Drawer_open_or_close',
#        'Writing,Buzz',
#        'Marimba_and_xylophone,Glockenspiel,Acoustic_guitar',
#        'Skateboard,Chewing_and_mastication',
#        'Bathtub_(filling_or_washing),Finger_snapping',
#        'Car_passing_by,Traffic_noise_and_roadway_noise',
#        'Car_passing_by,Church_bell,Buzz', 'Tap,Applause',
#        'Fill_(with_liquid),Sink_(filling_or_washing)',
#        'Bark,Finger_snapping', 'Cricket,Raindrop,Waves_and_surf',
#        'Computer_keyboard,Buzz', 'Bus,Meow',
#        'Chewing_and_mastication,Keys_jangling',
#        'Fill_(with_liquid),Drip,Gurgling', 'Shatter,Chirp_and_tweet',
#        'Bicycle_bell,Walk_and_footsteps',
#        'Cutlery_and_silverware,Chink_and_clink',
#        'Car_passing_by,Bus,Race_car_and_auto_racing',
#        'Whispering,Chewing_and_mastication', 'Squeak,Screaming',
#        'Bark,Bicycle_bell', 'Gasp,Writing', 'Sigh,Screaming',
#        'Bathtub_(filling_or_washing),Drip,Chewing_and_mastication',
#        'Bathtub_(filling_or_washing),Dishes_and_pots_and_pans,Cutlery_and_silverware',
#        'Sigh,Bass_guitar', 'Male_singing,Screaming',
#        'Chewing_and_mastication,Gurgling', 'Gasp,Knock',
#        'Fart,Burping_and_eructation', 'Shatter,Tap',
#        'Fill_(with_liquid),Water_tap_and_faucet,Toilet_flush,Sink_(filling_or_washing)',
#        'Computer_keyboard,Tick-tock',
#        'Zipper_(clothing),Shatter,Computer_keyboard,Scissors',
#        'Skateboard,Cupboard_open_or_close,Drawer_open_or_close',
#        'Chewing_and_mastication,Scissors', 'Writing,Crackle',
#        'Gasp,Screaming', 'Marimba_and_xylophone,Hi-hat',
#        'Squeak,Finger_snapping',
#        'Cupboard_open_or_close,Drawer_open_or_close,Knock',
#        'Dishes_and_pots_and_pans,Clapping',
#        'Water_tap_and_faucet,Microwave_oven,Drip,Chewing_and_mastication,Toilet_flush,Sink_(filling_or_washing)',
#        'Computer_keyboard,Chewing_and_mastication,Gurgling',
#        'Zipper_(clothing),Burping_and_eructation', 'Gasp,Sneeze',
#        'Finger_snapping,Scissors',
#        'Drip,Chewing_and_mastication,Toilet_flush',
#        'Burping_and_eructation,Finger_snapping', 'Raindrop,Frying_(food)',
#        'Gasp,Squeak', 'Drip,Keys_jangling',
#        'Screaming,Sink_(filling_or_washing)',
#        'Gasp,Whispering,Computer_keyboard,Sigh', 'Gasp,Whispering',
#        'Dishes_and_pots_and_pans,Printer,Cutlery_and_silverware',
#        'Car_passing_by,Strum,Electric_guitar',
#        'Water_tap_and_faucet,Drip,Toilet_flush,Sink_(filling_or_washing)',
#        'Zipper_(clothing),Crackle', 'Computer_keyboard,Scissors',
#        'Skateboard,Raindrop', 'Whispering,Finger_snapping,Scissors',
#        'Shatter,Chink_and_clink', 'Drip,Gurgling', 'Fart,Sigh,Buzz',
#        'Walk_and_footsteps,Chewing_and_mastication', 'Keys_jangling,Buzz',
#        'Tap,Cupboard_open_or_close', 'Cupboard_open_or_close,Meow',
#        'Tap,Slam', 'Tick-tock,Chink_and_clink',
#        'Accordion,Sigh,Harmonica', 'Fill_(with_liquid),Hiss,Toilet_flush',
#        'Fill_(with_liquid),Bathtub_(filling_or_washing),Water_tap_and_faucet',
#        'Bark,Cutlery_and_silverware', 'Zipper_(clothing),Finger_snapping',
#        'Computer_keyboard,Gurgling',
#        'Computer_keyboard,Strum,Bass_guitar', 'Writing,Keys_jangling',
#        'Strum,Electric_guitar,Crowd', 'Applause,Sneeze',
#        'Writing,Whispering,Chewing_and_mastication', 'Cricket,Hiss',
#        'Male_singing,Strum',
#        'Cupboard_open_or_close,Finger_snapping,Drawer_open_or_close,Clapping',
#        'Bus,Traffic_noise_and_roadway_noise',
#        'Fill_(with_liquid),Computer_keyboard,Drip', 'Purr,Meow',
#        'Car_passing_by,Slam', 'Computer_keyboard,Tick-tock,Knock',
#        'Fill_(with_liquid),Cutlery_and_silverware,Chink_and_clink',
#        'Bathtub_(filling_or_washing),Sneeze',
#        'Squeak,Chewing_and_mastication', 'Tap,Knock',
#        'Raindrop,Finger_snapping', 'Gasp,Sigh,Sneeze',
#        'Child_speech_and_kid_speaking,Drawer_open_or_close',
#        'Writing,Shatter', 'Cupboard_open_or_close,Knock,Buzz',
#        'Raindrop,Stream', 'Zipper_(clothing),Writing,Purr',
#        'Chewing_and_mastication,Finger_snapping,Scissors',
#        'Purr,Microwave_oven', 'Whispering,Meow',
#        'Car_passing_by,Microwave_oven', 'Male_singing,Female_singing',
#        'Car_passing_by,Motorcycle',
#        'Accelerating_and_revving_and_vroom,Printer',
#        'Drip,Trickle_and_dribble,Toilet_flush',
#        'Toilet_flush,Sink_(filling_or_washing)',
#        'Motorcycle,Waves_and_surf', 'Skateboard,Frying_(food)',
#        'Gurgling,Toilet_flush', 'Computer_keyboard,Chirp_and_tweet',
#        'Male_singing,Sigh,Screaming', 'Whispering,Drip', 'Hi-hat,Gong',
#        'Race_car_and_auto_racing,Keys_jangling',
#        'Skateboard,Waves_and_surf',
#        'Fill_(with_liquid),Burping_and_eructation',
#        'Marimba_and_xylophone,Glockenspiel,Female_singing,Harmonica',
#        'Dishes_and_pots_and_pans,Finger_snapping,Cutlery_and_silverware',
#        'Sneeze,Clapping',
#        'Car_passing_by,Accelerating_and_revving_and_vroom',
#        'Frying_(food),Scissors', 'Bicycle_bell,Motorcycle',
#        'Female_speech_and_woman_speaking,Sigh', 'Bark,Purr',
#        'Marimba_and_xylophone,Glockenspiel,Bicycle_bell',
#        'Gasp,Writing,Whispering', 'Zipper_(clothing),Purr',
#        'Shatter,Bass_drum,Hi-hat', 'Purr,Scissors',
#        'Computer_keyboard,Cupboard_open_or_close,Buzz',
#        'Water_tap_and_faucet,Trickle_and_dribble,Chirp_and_tweet,Toilet_flush,Sink_(filling_or_washing)',
#        'Zipper_(clothing),Fart,Burping_and_eructation',
#        'Bathtub_(filling_or_washing),Water_tap_and_faucet,Drip,Sink_(filling_or_washing)',
#        'Shatter,Male_speech_and_man_speaking',
#        'Shatter,Chink_and_clink,Knock', 'Writing,Chewing_and_mastication',
#        'Shatter,Tap,Slam,Toilet_flush', 'Gurgling,Crackle,Scissors',
#        'Purr,Screaming', 'Bicycle_bell,Printer',
#        'Bathtub_(filling_or_washing),Child_speech_and_kid_speaking,Cutlery_and_silverware,Chink_and_clink,Knock',
#        'Fill_(with_liquid),Drip,Chewing_and_mastication,Gurgling,Toilet_flush',
#        'Yell,Hi-hat', 'Strum,Tap,Applause', 'Zipper_(clothing),Hiss',
#        'Fill_(with_liquid),Water_tap_and_faucet,Drip,Scissors,Sink_(filling_or_washing)',
#        'Car_passing_by,Knock',
#        'Child_speech_and_kid_speaking,Burping_and_eructation,Sneeze',
#        'Bathtub_(filling_or_washing),Cupboard_open_or_close,Drawer_open_or_close',
#        'Microwave_oven,Accelerating_and_revving_and_vroom',
#        'Shatter,Cutlery_and_silverware', 'Female_singing,Clapping',
#        'Chewing_and_mastication,Sneeze', 'Writing,Cupboard_open_or_close',
#        'Skateboard,Bass_drum,Hi-hat', 'Writing,Whispering',
#        'Bathtub_(filling_or_washing),Water_tap_and_faucet,Toilet_flush,Sink_(filling_or_washing)',
#        'Race_car_and_auto_racing,Printer,Toilet_flush',
#        'Shatter,Computer_keyboard,Scissors,Toilet_flush',
#        'Bass_drum,Hi-hat,Bass_guitar',
#        'Female_speech_and_woman_speaking,Applause',
#        'Purr,Water_tap_and_faucet,Drip,Chewing_and_mastication,Trickle_and_dribble,Toilet_flush,Sink_(filling_or_washing)',
#        'Finger_snapping,Sneeze',
#        'Burping_and_eructation,Cutlery_and_silverware',
#        'Bathtub_(filling_or_washing),Tick-tock',
#        'Shatter,Accelerating_and_revving_and_vroom',
#        'Marimba_and_xylophone,Female_singing',
#        'Bicycle_bell,Cupboard_open_or_close,Keys_jangling,Scissors',
#        'Writing,Purr', 'Motorcycle,Traffic_noise_and_roadway_noise',
#        'Squeak,Printer', 'Chewing_and_mastication,Chink_and_clink',
#        'Raindrop,Gurgling', 'Frying_(food),Screaming',
#        'Shatter,Drawer_open_or_close', 'Bicycle_bell,Toilet_flush',
#        'Fill_(with_liquid),Drip,Toilet_flush', 'Bus,Gong',
#        'Zipper_(clothing),Hi-hat',
#        'Accelerating_and_revving_and_vroom,Keys_jangling', 'Bark,Squeak',
#        'Meow,Buzz',
#        'Fill_(with_liquid),Water_tap_and_faucet,Drip,Toilet_flush,Sink_(filling_or_washing)',
#        'Fill_(with_liquid),Water_tap_and_faucet,Chewing_and_mastication,Sink_(filling_or_washing)',
#        'Burping_and_eructation,Sneeze', 'Purr,Chewing_and_mastication',
#        'Writing,Computer_keyboard,Finger_snapping',
#        'Drip,Gurgling,Toilet_flush', 'Tick-tock,Gong',
#        'Bass_drum,Hi-hat,Acoustic_guitar', 'Bark,Chewing_and_mastication',
#        'Bicycle_bell,Male_speech_and_man_speaking,Chink_and_clink',
#        'Chink_and_clink,Church_bell,Harmonica,Toilet_flush',
#        'Race_car_and_auto_racing,Motorcycle',
#        'Applause,Male_speech_and_man_speaking',
#        'Fill_(with_liquid),Drip,Chewing_and_mastication',
#        'Computer_keyboard,Water_tap_and_faucet,Drip',
#        'Gasp,Writing,Purr,Sneeze', 'Zipper_(clothing),Crackle,Scissors',
#        'Writing,Church_bell', 'Whispering,Sneeze',
#        'Water_tap_and_faucet,Drip,Gurgling,Sink_(filling_or_washing)',
#        'Printer,Buzz', 'Tick-tock,Toilet_flush', 'Screaming,Knock',
#        'Gasp,Gurgling', 'Writing,Mechanical_fan',
#        'Zipper_(clothing),Gasp,Fart,Sneeze',
#        'Gasp,Cupboard_open_or_close,Sigh,Knock,Church_bell',
#        'Squeak,Chirp_and_tweet',
#        'Writing,Microwave_oven,Keys_jangling,Scissors',
#        'Fill_(with_liquid),Computer_keyboard,Drip,Gurgling',
#        'Gurgling,Knock', 'Child_speech_and_kid_speaking,Buzz',
#        'Writing,Whispering,Finger_snapping', 'Cricket,Crackle',
#        'Gasp,Sigh,Knock', 'Walk_and_footsteps,Chirp_and_tweet',
#        'Zipper_(clothing),Buzz', 'Writing,Fart', 'Fart,Sigh',
#        'Bathtub_(filling_or_washing),Cutlery_and_silverware',
#        'Writing,Computer_keyboard', 'Tick-tock,Drip', 'Cricket,Purr',
#        'Fart,Cupboard_open_or_close', 'Mechanical_fan,Bass_drum,Hi-hat',
#        'Dishes_and_pots_and_pans,Cutlery_and_silverware,Scissors',
#        'Microwave_oven,Keys_jangling', 'Fart,Tick-tock',
#        'Frying_(food),Clapping', 'Bass_drum,Bass_guitar',
#        'Writing,Computer_keyboard,Keys_jangling,Scissors',
#        'Tick-tock,Screaming', 'Bus,Waves_and_surf',
#        'Bathtub_(filling_or_washing),Screaming', 'Male_singing,Purr',
#        'Gasp,Hiss',
#        'Fill_(with_liquid),Water_tap_and_faucet,Sink_(filling_or_washing)',
#        'Bicycle_bell,Run',
#        'Marimba_and_xylophone,Bicycle_bell,Keys_jangling',
#        'Skateboard,Crackle',
#        'Car_passing_by,Cupboard_open_or_close,Knock',
#        'Tick-tock,Cutlery_and_silverware', 'Writing,Whispering,Sneeze',
#        'Zipper_(clothing),Race_car_and_auto_racing',
#        'Female_singing,Harmonica', 'Writing,Chirp_and_tweet',
#        'Shatter,Sigh', 'Computer_keyboard,Keys_jangling',
#        'Whispering,Keys_jangling',
#        'Fill_(with_liquid),Raindrop,Trickle_and_dribble', 'Run,Crowd',
#        'Yell,Electric_guitar', 'Bark,Bathtub_(filling_or_washing)',
#        'Bicycle_bell,Harmonica', 'Raindrop,Water_tap_and_faucet',
#        'Fill_(with_liquid),Water_tap_and_faucet,Toilet_flush',
#        'Acoustic_guitar,Harmonica', 'Female_singing,Gong',
#        'Mechanical_fan,Microwave_oven',
#        'Tap,Cupboard_open_or_close,Finger_snapping', 'Applause,Cheering',
#        'Computer_keyboard,Sneeze', 'Tap,Electric_guitar',
#        'Keys_jangling,Scissors,Buzz', 'Strum,Meow,Electric_guitar',
#        'Strum,Acoustic_guitar,Harmonica', 'Bass_guitar,Electric_guitar',
#        'Female_speech_and_woman_speaking,Child_speech_and_kid_speaking',
#        'Glockenspiel,Sigh', 'Trickle_and_dribble,Slam',
#        'Microwave_oven,Scissors',
#        'Water_tap_and_faucet,Toilet_flush,Sink_(filling_or_washing)',
#        'Fill_(with_liquid),Cricket',
#        'Fill_(with_liquid),Drip,Trickle_and_dribble,Toilet_flush',
#        'Keys_jangling,Crackle,Scissors',
#        'Skateboard,Dishes_and_pots_and_pans,Cutlery_and_silverware',
#        'Zipper_(clothing),Fart,Finger_snapping',
#        'Female_speech_and_woman_speaking,Female_singing,Clapping',
#        'Tick-tock,Female_singing', 'Shatter,Cupboard_open_or_close',
#        'Accelerating_and_revving_and_vroom,Knock',
#        'Computer_keyboard,Chewing_and_mastication,Scissors',
#        'Fill_(with_liquid),Drip,Trickle_and_dribble',
#        'Frying_(food),Cupboard_open_or_close',
#        'Bass_guitar,Acoustic_guitar', 'Strum,Gong',
#        'Cupboard_open_or_close,Dishes_and_pots_and_pans,Cutlery_and_silverware',
#        'Tap,Finger_snapping,Clapping',
#        'Male_singing,Marimba_and_xylophone,Glockenspiel',
#        'Gasp,Burping_and_eructation,Sigh', 'Bicycle_bell,Finger_snapping',
#        'Fill_(with_liquid),Bathtub_(filling_or_washing),Water_tap_and_faucet,Drip,Trickle_and_dribble,Toilet_flush,Sink_(filling_or_washing)',
#        'Computer_keyboard,Printer', 'Zipper_(clothing),Gasp,Sneeze',
#        'Whispering,Dishes_and_pots_and_pans,Cutlery_and_silverware,Clapping',
#        'Squeak,Sneeze', 'Child_speech_and_kid_speaking,Screaming',
#        'Shatter,Walk_and_footsteps', 'Microwave_oven,Printer,Buzz',
#        'Water_tap_and_faucet,Drip,Toilet_flush',
#        'Gasp,Sigh,Finger_snapping,Sneeze', 'Shatter,Hiss',
#        'Dishes_and_pots_and_pans,Cutlery_and_silverware,Drawer_open_or_close',
#        'Tick-tock,Scissors', 'Gasp,Skateboard,Sigh,Gurgling',
#        'Bark,Sneeze,Buzz',
#        'Marimba_and_xylophone,Glockenspiel,Church_bell',
#        'Shatter,Dishes_and_pots_and_pans,Keys_jangling,Cutlery_and_silverware,Chink_and_clink,Scissors',
#        'Tick-tock,Cutlery_and_silverware,Scissors',
#        'Bathtub_(filling_or_washing),Burping_and_eructation',
#        'Printer,Knock',
#        'Bathtub_(filling_or_washing),Water_tap_and_faucet,Frying_(food)',
#        'Tap,Cupboard_open_or_close,Knock', 'Fart,Sneeze', 'Purr,Fart',
#        'Yell,Bass_guitar',
#        'Squeak,Drip,Chewing_and_mastication,Finger_snapping',
#        'Gasp,Scissors',
#        'Raindrop,Water_tap_and_faucet,Sink_(filling_or_washing)',
#        'Fill_(with_liquid),Trickle_and_dribble,Toilet_flush',
#        'Zipper_(clothing),Gasp,Sigh',
#        'Gasp,Writing,Finger_snapping,Sneeze',
#        'Fill_(with_liquid),Water_tap_and_faucet,Hiss,Toilet_flush,Sink_(filling_or_washing)',
#        'Yell,Sigh', 'Zipper_(clothing),Child_speech_and_kid_speaking',
#        'Zipper_(clothing),Scissors', 'Tap,Knock,Buzz',
#        'Computer_keyboard,Tap',
#        'Bathtub_(filling_or_washing),Water_tap_and_faucet,Sink_(filling_or_washing)',
#        'Car_passing_by,Race_car_and_auto_racing,Accelerating_and_revving_and_vroom,Electric_guitar,Gong',
#        'Gasp,Child_speech_and_kid_speaking',
#        'Burping_and_eructation,Printer',
#        'Waves_and_surf,Traffic_noise_and_roadway_noise',
#        'Bicycle_bell,Sigh',
#        'Female_speech_and_woman_speaking,Applause,Male_speech_and_man_speaking',
#        'Drip,Sink_(filling_or_washing)', 'Squeak,Screaming,Buzz',
#        'Water_tap_and_faucet,Trickle_and_dribble',
#        'Water_tap_and_faucet,Hiss,Sink_(filling_or_washing)',
#        'Female_speech_and_woman_speaking,Water_tap_and_faucet,Sink_(filling_or_washing)',
#        'Writing,Bicycle_bell',
#        'Water_tap_and_faucet,Microwave_oven,Sink_(filling_or_washing)',
#        'Computer_keyboard,Fart,Scissors',
#        'Drip,Chewing_and_mastication,Sink_(filling_or_washing)',
#        'Squeak,Microwave_oven', 'Gasp,Tick-tock', 'Gasp,Squeak,Sneeze',
#        'Bicycle_bell,Water_tap_and_faucet', 'Gasp,Writing,Scissors',
#        'Zipper_(clothing),Shatter', 'Shatter,Squeak',
#        'Fill_(with_liquid),Computer_keyboard,Drip,Chewing_and_mastication,Scissors',
#        'Gasp,Computer_keyboard', 'Fart,Scissors',
#        'Fill_(with_liquid),Toilet_flush,Sink_(filling_or_washing)',
#        'Skateboard,Hiss', 'Gasp,Sigh,Knock,Buzz',
#        'Accordion,Electric_guitar', 'Zipper_(clothing),Knock,Buzz',
#        'Bass_guitar,Male_speech_and_man_speaking', 'Car_passing_by,Bus',
#        'Car_passing_by,Cupboard_open_or_close',
#        'Whispering,Burping_and_eructation',
#        'Bathtub_(filling_or_washing),Dishes_and_pots_and_pans,Cutlery_and_silverware,Chink_and_clink',
#        'Strum,Electric_guitar,Harmonica', 'Male_singing,Church_bell',
#        'Race_car_and_auto_racing,Buzz', 'Run,Cheering',
#        'Frying_(food),Dishes_and_pots_and_pans,Cutlery_and_silverware,Toilet_flush',
#        'Bathtub_(filling_or_washing),Water_tap_and_faucet,Frying_(food),Sink_(filling_or_washing)',
#        'Writing,Computer_keyboard,Tick-tock,Chewing_and_mastication,Keys_jangling,Scissors',
#        'Zipper_(clothing),Fart,Water_tap_and_faucet,Sink_(filling_or_washing)',
#        'Marimba_and_xylophone,Glockenspiel,Gong',
#        'Squeak,Child_speech_and_kid_speaking',
#        'Zipper_(clothing),Purr,Child_speech_and_kid_speaking',
#        'Frying_(food),Toilet_flush', 'Squeak,Harmonica',
#        'Glockenspiel,Tick-tock', 'Cupboard_open_or_close,Slam',
#        'Raindrop,Church_bell', 'Fart,Buzz',
#        'Writing,Finger_snapping,Scissors',
#        'Bass_drum,Hi-hat,Electric_guitar', 'Keys_jangling,Crackle',
#        'Bass_guitar,Keys_jangling',
#        'Burping_and_eructation,Chewing_and_mastication',
#        'Bicycle_bell,Crackle', 'Squeak,Clapping',
#        'Finger_snapping,Drawer_open_or_close', 'Motorcycle,Skateboard',
#        'Sigh,Sneeze', 'Hi-hat,Finger_snapping', 'Meow,Knock',
#        'Bicycle_bell,Scissors',
#        'Fart,Dishes_and_pots_and_pans,Cutlery_and_silverware',
#        'Finger_snapping,Chink_and_clink', 'Bark,Sneeze',
#        'Writing,Drip,Chewing_and_mastication',
#        'Fill_(with_liquid),Bathtub_(filling_or_washing),Water_tap_and_faucet,Toilet_flush,Sink_(filling_or_washing)',
#        'Whispering,Purr', 'Squeak,Frying_(food)',
#        'Chewing_and_mastication,Trickle_and_dribble',
#        'Strum,Acoustic_guitar,Electric_guitar', 'Zipper_(clothing),Crowd',
#        'Whispering,Computer_keyboard,Chewing_and_mastication',
#        'Fill_(with_liquid),Water_tap_and_faucet,Stream,Trickle_and_dribble,Toilet_flush',
#        'Bicycle_bell,Squeak,Scissors,Knock', 'Shatter,Skateboard,Knock',
#        'Fart,Child_speech_and_kid_speaking', 'Hiss,Keys_jangling',
#        'Frying_(food),Burping_and_eructation,Dishes_and_pots_and_pans,Cutlery_and_silverware,Drawer_open_or_close',
#        'Bass_drum,Hi-hat,Chink_and_clink', 'Male_singing,Harmonica',
#        'Writing,Sneeze', 'Zipper_(clothing),Writing,Shatter',
#        'Glockenspiel,Meow', 'Cupboard_open_or_close,Buzz',
#        'Bicycle_bell,Cupboard_open_or_close',
#        'Male_singing,Strum,Female_singing,Electric_guitar',
#        'Stream,Waves_and_surf', 'Bus,Cupboard_open_or_close',
#        'Purr,Squeak', 'Fart,Meow',
#        'Marimba_and_xylophone,Glockenspiel,Chink_and_clink',
#        'Whispering,Crackle', 'Gasp,Motorcycle,Sneeze', 'Squeak,Scissors',
#        'Glockenspiel,Gong', 'Marimba_and_xylophone,Glockenspiel,Strum',
#        'Child_speech_and_kid_speaking,Cupboard_open_or_close',
#        'Purr,Computer_keyboard,Keys_jangling', 'Writing,Frying_(food)',
#        'Cheering,Slam', 'Fart,Crackle', 'Hiss,Gong', 'Shatter,Screaming',
#        'Whispering,Squeak', 'Drip,Toilet_flush,Sink_(filling_or_washing)',
#        'Fill_(with_liquid),Hiss,Trickle_and_dribble,Toilet_flush',
#        'Frying_(food),Trickle_and_dribble',
#        'Zipper_(clothing),Squeak,Meow',
#        'Drip,Cutlery_and_silverware,Chink_and_clink',
#        'Water_tap_and_faucet,Drip,Frying_(food),Toilet_flush,Sink_(filling_or_washing)',
#        'Gasp,Fill_(with_liquid),Burping_and_eructation,Sigh',
#        'Fart,Screaming', 'Skateboard,Keys_jangling',
#        'Computer_keyboard,Dishes_and_pots_and_pans,Cutlery_and_silverware',
#        'Water_tap_and_faucet,Microwave_oven',
#        'Zipper_(clothing),Fart,Buzz', 'Squeak,Chink_and_clink',
#        'Water_tap_and_faucet,Toilet_flush', 'Bark,Microwave_oven',
#        'Male_singing,Printer', 'Yell,Toilet_flush',
#        'Race_car_and_auto_racing,Fart', 'Whispering,Sigh',
#        'Car_passing_by,Cheering', 'Applause,Crowd',
#        'Tap,Drawer_open_or_close,Clapping', 'Male_singing,Crowd',
#        'Bark,Writing,Bicycle_bell,Squeak,Sneeze', 'Fart,Finger_snapping',
#        'Shatter,Computer_keyboard,Tap,Sink_(filling_or_washing)',
#        'Gasp,Bathtub_(filling_or_washing)', 'Electric_guitar,Gong',
#        'Zipper_(clothing),Bark',
#        'Zipper_(clothing),Fill_(with_liquid),Sink_(filling_or_washing)',
#        'Mechanical_fan,Traffic_noise_and_roadway_noise',
#        'Zipper_(clothing),Squeak', 'Shatter,Knock',
#        'Zipper_(clothing),Squeak,Sigh,Chewing_and_mastication,Crackle',
#        'Tick-tock,Keys_jangling',
#        'Gasp,Fill_(with_liquid),Burping_and_eructation,Sigh,Sink_(filling_or_washing)',
#        'Zipper_(clothing),Writing,Squeak', 'Gasp,Fart,Sigh,Screaming',
#        'Printer,Harmonica', 'Male_singing,Applause',
#        'Computer_keyboard,Chink_and_clink', 'Bark,Fart',
#        'Bicycle_bell,Keys_jangling', 'Hiss,Gurgling,Toilet_flush',
#        'Cricket,Mechanical_fan',
#        'Zipper_(clothing),Walk_and_footsteps,Crackle',
#        'Hi-hat,Acoustic_guitar', 'Car_passing_by,Chirp_and_tweet',
#        'Tap,Gong', 'Shatter,Chirp_and_tweet,Scissors',
#        'Writing,Purr,Scissors',
#        'Raindrop,Water_tap_and_faucet,Frying_(food)', 'Bus,Keys_jangling',
#        'Shatter,Frying_(food),Hi-hat,Bass_guitar',
#        'Tap,Burping_and_eructation,Finger_snapping',
#        'Dishes_and_pots_and_pans,Meow', 'Yell,Crowd',
#        'Shatter,Motorcycle', 'Glockenspiel,Screaming',
#        'Glockenspiel,Whispering',
#        'Water_tap_and_faucet,Frying_(food),Scissors',
#        'Gasp,Squeak,Burping_and_eructation',
#        'Drip,Chewing_and_mastication,Gurgling',
#        'Zipper_(clothing),Sneeze,Buzz', 'Printer,Drawer_open_or_close',
#        'Writing,Purr,Fart', 'Computer_keyboard,Crackle',
#        'Male_singing,Child_speech_and_kid_speaking',
#        'Zipper_(clothing),Gasp,Car_passing_by', 'Mechanical_fan,Crackle',
#        'Finger_snapping,Sneeze,Scissors', 'Tick-tock,Meow',
#        'Whispering,Clapping', 'Drip,Hi-hat,Keys_jangling,Chink_and_clink',
#        'Marimba_and_xylophone,Glockenspiel,Hi-hat',
#        'Bark,Cupboard_open_or_close,Finger_snapping', 'Yell,Bass_drum',
#        'Bass_drum,Hi-hat,Gong', 'Run,Skateboard', 'Bark,Crackle',
#        'Bathtub_(filling_or_washing),Fart,Burping_and_eructation',
#        'Writing,Bus',
#        'Fill_(with_liquid),Water_tap_and_faucet,Cupboard_open_or_close,Sink_(filling_or_washing)',
#        'Race_car_and_auto_racing,Traffic_noise_and_roadway_noise',
#        'Car_passing_by,Sigh', 'Trickle_and_dribble,Toilet_flush',
#        'Applause,Sigh',
#        'Fill_(with_liquid),Water_tap_and_faucet,Stream,Sink_(filling_or_washing)',
#        'Fill_(with_liquid),Scissors',
#        'Male_singing,Marimba_and_xylophone',
#        'Screaming,Male_speech_and_man_speaking',
#        'Tap,Dishes_and_pots_and_pans', 'Male_singing,Bark,Clapping',
#        'Gasp,Drip', 'Zipper_(clothing),Squeak,Fart,Finger_snapping',
#        'Frying_(food),Cutlery_and_silverware',
#        'Zipper_(clothing),Purr,Crackle',
#        'Fill_(with_liquid),Bicycle_bell',
#        'Shatter,Keys_jangling,Chink_and_clink',
#        'Bicycle_bell,Dishes_and_pots_and_pans,Cutlery_and_silverware',
#        'Purr,Knock',
#        'Purr,Dishes_and_pots_and_pans,Cutlery_and_silverware',
#        'Strum,Hi-hat,Electric_guitar',
#        'Hi-hat,Bass_guitar,Acoustic_guitar',
#        'Keys_jangling,Printer,Scissors',
#        'Shatter,Cupboard_open_or_close,Sneeze,Slam',
#        'Sigh,Hi-hat,Bass_guitar',
#        'Race_car_and_auto_racing,Frying_(food),Accelerating_and_revving_and_vroom',
#        'Bus,Knock', 'Strum,Female_singing', 'Walk_and_footsteps,Sneeze',
#        'Purr,Tick-tock', 'Knock,Buzz', 'Zipper_(clothing),Gasp,Fart',
#        'Meow,Finger_snapping', 'Shatter,Drip', 'Writing,Printer',
#        'Hiss,Chink_and_clink', 'Motorcycle,Fart',
#        'Writing,Walk_and_footsteps', 'Chirp_and_tweet,Church_bell',
#        'Shatter,Bass_guitar',
#        'Bark,Frying_(food),Dishes_and_pots_and_pans,Cutlery_and_silverware',
#        'Skateboard,Gurgling', 'Drip,Toilet_flush', 'Run,Gurgling',
#        'Zipper_(clothing),Fart,Skateboard,Crackle',
#        'Male_speech_and_man_speaking,Chirp_and_tweet,Harmonica,Buzz',
#        'Male_singing,Male_speech_and_man_speaking', 'Gasp,Bark',
#        'Run,Screaming',
#        'Whispering,Child_speech_and_kid_speaking,Scissors',
#        'Strum,Bass_guitar,Acoustic_guitar,Electric_guitar',
#        'Bark,Keys_jangling', 'Bass_drum,Electric_guitar',
#        'Zipper_(clothing),Fart,Burping_and_eructation,Sneeze',
#        'Marimba_and_xylophone,Glockenspiel,Electric_guitar',
#        'Acoustic_guitar,Chirp_and_tweet', 'Shatter,Hiss,Keys_jangling',
#        'Fill_(with_liquid),Computer_keyboard,Drip,Chewing_and_mastication,Knock',
#        'Bus,Microwave_oven,Keys_jangling,Gong',
#        'Drip,Trickle_and_dribble,Cutlery_and_silverware',
#        'Male_singing,Dishes_and_pots_and_pans',
#        'Zipper_(clothing),Race_car_and_auto_racing,Fart',
#        'Whispering,Bathtub_(filling_or_washing),Sneeze',
#        'Female_speech_and_woman_speaking,Toilet_flush',
#        'Microwave_oven,Printer', 'Burping_and_eructation,Screaming',
#        'Purr,Cupboard_open_or_close,Cutlery_and_silverware',
#        'Female_speech_and_woman_speaking,Run',
#        'Whispering,Finger_snapping', 'Meow,Church_bell',
#        'Fill_(with_liquid),Water_tap_and_faucet,Hiss,Gurgling,Toilet_flush,Sink_(filling_or_washing)',
#        'Marimba_and_xylophone,Glockenspiel,Bass_drum,Bass_guitar',
#        'Mechanical_fan,Raindrop', 'Sigh,Male_speech_and_man_speaking',
#        'Fill_(with_liquid),Gurgling', 'Finger_snapping,Buzz',
#        'Computer_keyboard,Chewing_and_mastication,Keys_jangling',
#        'Bathtub_(filling_or_washing),Drip,Sink_(filling_or_washing)',
#        'Shatter,Cutlery_and_silverware,Chink_and_clink',
#        'Whispering,Chewing_and_mastication,Chirp_and_tweet',
#        'Fill_(with_liquid),Bathtub_(filling_or_washing),Water_tap_and_faucet,Sink_(filling_or_washing)',
#        'Yell,Accelerating_and_revving_and_vroom', 'Purr,Buzz',
#        'Raindrop,Cupboard_open_or_close,Knock,Slam',
#        'Printer,Toilet_flush', 'Drip,Chewing_and_mastication,Scissors',
#        'Cricket,Squeak',
#        'Tap,Dishes_and_pots_and_pans,Drawer_open_or_close',
#        'Gasp,Dishes_and_pots_and_pans,Cutlery_and_silverware',
#        'Gasp,Fart', 'Bark,Computer_keyboard',
#        'Bicycle_bell,Frying_(food)', 'Drip,Hiss',
#        'Shatter,Mechanical_fan,Hiss,Chink_and_clink',
#        'Church_bell,Harmonica,Gong', 'Gasp,Finger_snapping',
#        'Water_tap_and_faucet,Hiss,Toilet_flush',
#        'Zipper_(clothing),Screaming,Crackle', 'Gasp,Keys_jangling,Knock',
#        'Gasp,Bathtub_(filling_or_washing),Cupboard_open_or_close,Drawer_open_or_close',
#        'Gasp,Sigh,Screaming,Knock,Slam',
#        'Computer_keyboard,Bathtub_(filling_or_washing)',
#        'Male_singing,Bus', 'Car_passing_by,Race_car_and_auto_racing,Gong',
#        'Water_tap_and_faucet,Dishes_and_pots_and_pans,Cutlery_and_silverware,Sink_(filling_or_washing)',
#        'Walk_and_footsteps,Keys_jangling',
#        'Whispering,Walk_and_footsteps,Chewing_and_mastication',
#        'Zipper_(clothing),Race_car_and_auto_racing,Motorcycle',
#        'Zipper_(clothing),Sigh,Sneeze',
#        'Bathtub_(filling_or_washing),Drip,Trickle_and_dribble',
#        'Yell,Harmonica', 'Gasp,Burping_and_eructation,Sigh,Sneeze',
#        'Fill_(with_liquid),Race_car_and_auto_racing', 'Motorcycle,Gong',
#        'Tick-tock,Drawer_open_or_close',
#        'Cupboard_open_or_close,Drawer_open_or_close,Gong',
#        'Male_singing,Finger_snapping', 'Chirp_and_tweet,Gong',
#        'Shatter,Bicycle_bell,Chink_and_clink',
#        'Drip,Burping_and_eructation', 'Whispering,Walk_and_footsteps',
#        'Frying_(food),Sigh',
#        'Fill_(with_liquid),Bathtub_(filling_or_washing),Water_tap_and_faucet,Toilet_flush',
#        'Chewing_and_mastication,Crackle', 'Purr,Squeak,Screaming',
#        'Bathtub_(filling_or_washing),Female_singing',
#        'Chewing_and_mastication,Finger_snapping', 'Bus,Church_bell',
#        'Burping_and_eructation,Scissors', 'Whispering,Fart,Sigh',
#        'Squeak,Dishes_and_pots_and_pans,Cutlery_and_silverware',
#        'Cricket,Bicycle_bell,Crackle,Church_bell,Gong',
#        'Burping_and_eructation,Sigh',
#        'Gasp,Writing,Finger_snapping,Scissors',
#        'Computer_keyboard,Child_speech_and_kid_speaking',
#        'Accelerating_and_revving_and_vroom,Gong',
#        'Run,Chewing_and_mastication,Crackle',
#        'Writing,Whispering,Scissors',
#        'Zipper_(clothing),Car_passing_by,Buzz', 'Raindrop,Keys_jangling',
#        'Fill_(with_liquid),Printer', 'Zipper_(clothing),Car_passing_by',
#        'Fart,Burping_and_eructation,Finger_snapping',
#        'Water_tap_and_faucet,Gurgling,Sink_(filling_or_washing)',
#        'Skateboard,Cupboard_open_or_close',
#        'Chink_and_clink,Traffic_noise_and_roadway_noise',
#        'Whispering,Child_speech_and_kid_speaking',
#        'Frying_(food),Drawer_open_or_close',
#        'Whispering,Bathtub_(filling_or_washing)',
#        'Whispering,Squeak,Sneeze', 'Computer_keyboard,Mechanical_fan',
#        'Computer_keyboard,Cutlery_and_silverware',
#        'Cupboard_open_or_close,Printer,Drawer_open_or_close',
#        'Zipper_(clothing),Race_car_and_auto_racing,Accelerating_and_revving_and_vroom',
#        'Trickle_and_dribble,Crackle', 'Writing,Clapping',
#        'Shatter,Hi-hat,Chink_and_clink',
#        'Child_speech_and_kid_speaking,Dishes_and_pots_and_pans,Cutlery_and_silverware',
#        'Water_tap_and_faucet,Drip,Chink_and_clink',
#        'Glockenspiel,Chink_and_clink',
#        'Computer_keyboard,Sneeze,Drawer_open_or_close',
#        'Gasp,Chewing_and_mastication,Finger_snapping',
#        'Zipper_(clothing),Gasp,Writing,Fart,Chewing_and_mastication,Finger_snapping,Scissors',
#        'Purr,Fart,Finger_snapping', 'Gasp,Hiss,Gurgling',
#        'Fill_(with_liquid),Shatter', 'Car_passing_by,Finger_snapping',
#        'Shatter,Crackle',
#        'Bark,Race_car_and_auto_racing,Accelerating_and_revving_and_vroom',
#        'Gasp,Sigh,Chirp_and_tweet,Knock',
#        'Drip,Chewing_and_mastication,Trickle_and_dribble,Toilet_flush',
#        'Water_tap_and_faucet,Trickle_and_dribble,Toilet_flush,Sink_(filling_or_washing)',
#        'Fill_(with_liquid),Cricket,Toilet_flush',
#        'Glockenspiel,Burping_and_eructation',
#        'Water_tap_and_faucet,Tick-tock', 'Bass_drum,Church_bell',
#        'Whispering,Fart', 'Screaming,Crowd',
#        'Zipper_(clothing),Microwave_oven',
#        'Cupboard_open_or_close,Printer,Knock,Slam',
#        'Computer_keyboard,Water_tap_and_faucet,Keys_jangling,Scissors,Sink_(filling_or_washing)',
#        'Chewing_and_mastication,Toilet_flush,Sink_(filling_or_washing)',
#        'Applause,Harmonica',
#        'Female_speech_and_woman_speaking,Female_singing',
#        'Zipper_(clothing),Squeak,Screaming', 'Strum,Harmonica',
#        'Gasp,Bass_guitar,Finger_snapping',
#        'Shatter,Chewing_and_mastication,Keys_jangling,Chink_and_clink,Scissors',
#        'Female_speech_and_woman_speaking,Clapping',
#        'Child_speech_and_kid_speaking,Meow,Drawer_open_or_close',
#        'Computer_keyboard,Drip,Chewing_and_mastication,Gurgling',
#        'Car_passing_by,Bicycle_bell', 'Gasp,Sigh,Acoustic_guitar',
#        'Bark,Screaming', 'Cricket,Walk_and_footsteps',
#        'Dishes_and_pots_and_pans,Cutlery_and_silverware,Clapping',
#        'Zipper_(clothing),Computer_keyboard,Fart,Scissors',
#        'Zipper_(clothing),Sigh,Screaming',
#        'Computer_keyboard,Scissors,Knock,Sink_(filling_or_washing)',
#        'Gasp,Bicycle_bell', 'Knock,Clapping', 'Gasp,Whispering,Fart',
#        'Computer_keyboard,Hi-hat,Acoustic_guitar',
#        'Computer_keyboard,Finger_snapping,Scissors',
#        'Marimba_and_xylophone,Glockenspiel,Shatter',
#        'Cupboard_open_or_close,Screaming',
#        'Bathtub_(filling_or_washing),Child_speech_and_kid_speaking,Dishes_and_pots_and_pans,Cutlery_and_silverware',
#        'Skateboard,Cheering', 'Whispering,Squeak,Crackle',
#        'Applause,Scissors',
#        'Writing,Squeak,Child_speech_and_kid_speaking',
#        'Gasp,Whispering,Burping_and_eructation,Finger_snapping',
#        'Shatter,Keys_jangling,Slam',
#        'Gasp,Squeak,Fart,Sigh,Finger_snapping,Screaming,Sneeze',
#        'Cricket,Scissors,Buzz', 'Zipper_(clothing),Knock',
#        'Raindrop,Applause',
#        'Raindrop,Chink_and_clink,Drawer_open_or_close,Slam',
#        'Sneeze,Knock', 'Microwave_oven,Hiss', 'Hiss,Gurgling',
#        'Water_tap_and_faucet,Drip,Trickle_and_dribble,Sink_(filling_or_washing)',
#        'Chink_and_clink,Sneeze',
#        'Bathtub_(filling_or_washing),Water_tap_and_faucet,Drip,Dishes_and_pots_and_pans,Sink_(filling_or_washing)',
#        'Mechanical_fan,Cupboard_open_or_close,Buzz',
#        'Burping_and_eructation,Chink_and_clink',
#        'Marimba_and_xylophone,Glockenspiel,Shatter,Chink_and_clink',
#        'Shatter,Slam', 'Frying_(food),Buzz',
#        'Buzz,Sink_(filling_or_washing)', 'Sneeze,Scissors',
#        'Squeak,Finger_snapping,Sneeze', 'Church_bell,Harmonica',
#        'Fill_(with_liquid),Hiss', 'Squeak,Buzz',
#        'Raindrop,Chirp_and_tweet', 'Writing,Purr,Crackle',
#        'Male_singing,Strum,Acoustic_guitar', 'Cricket,Scissors',
#        'Bark,Dishes_and_pots_and_pans,Cutlery_and_silverware',
#        'Gasp,Writing,Sigh',
#        'Frying_(food),Cutlery_and_silverware,Chink_and_clink',
#        'Frying_(food),Dishes_and_pots_and_pans',
#        'Zipper_(clothing),Gasp,Writing,Scissors',
#        'Microwave_oven,Toilet_flush',
#        'Tick-tock,Cupboard_open_or_close,Knock',
#        'Squeak,Burping_and_eructation,Screaming',
#        'Chewing_and_mastication,Keys_jangling,Scissors',
#        'Whispering,Finger_snapping,Clapping', 'Bass_drum,Female_singing',
#        'Fill_(with_liquid),Skateboard', 'Bark,Harmonica',
#        'Tap,Child_speech_and_kid_speaking,Finger_snapping,Clapping',
#        'Male_singing,Clapping',
#        'Shatter,Bicycle_bell,Walk_and_footsteps,Chink_and_clink',
#        'Mechanical_fan,Church_bell',
#        'Fill_(with_liquid),Male_speech_and_man_speaking',
#        'Male_singing,Female_singing,Buzz',
#        'Strum,Female_singing,Electric_guitar',
#        'Applause,Sigh,Male_speech_and_man_speaking', 'Bark,Clapping',
#        'Sigh,Finger_snapping,Sneeze', 'Mechanical_fan,Waves_and_surf',
#        'Hiss,Stream', 'Bass_guitar,Harmonica',
#        'Walk_and_footsteps,Chewing_and_mastication,Crackle',
#        'Writing,Chink_and_clink', 'Whispering,Sigh,Sneeze',
#        'Writing,Chewing_and_mastication,Scissors',
#        'Gasp,Whispering,Sneeze',
#        'Computer_keyboard,Keys_jangling,Gurgling', 'Shatter,Gong',
#        'Burping_and_eructation,Walk_and_footsteps',
#        'Microwave_oven,Frying_(food)',
#        'Fill_(with_liquid),Accelerating_and_revving_and_vroom',
#        'Raindrop,Drip,Crackle', 'Shatter,Bicycle_bell',
#        'Tick-tock,Microwave_oven,Keys_jangling', 'Strum,Bass_guitar',
#        'Bathtub_(filling_or_washing),Scissors', 'Run,Raindrop',
#        'Shatter,Knock,Toilet_flush', 'Hiss,Crowd',
#        'Fill_(with_liquid),Bathtub_(filling_or_washing)',
#        'Tick-tock,Buzz', 'Sigh,Chewing_and_mastication',
#        'Printer,Male_speech_and_man_speaking', 'Zipper_(clothing),Sigh',
#        'Zipper_(clothing),Finger_snapping,Knock',
#        'Squeak,Bathtub_(filling_or_washing)', 'Cricket,Raindrop',
#        'Strum,Printer',
#        'Shatter,Computer_keyboard,Chewing_and_mastication,Keys_jangling',
#        'Writing,Squeak', 'Gasp,Fill_(with_liquid),Drip,Toilet_flush',
#        'Zipper_(clothing),Computer_keyboard', 'Male_singing,Bass_drum',
#        'Bass_drum,Hi-hat,Female_singing', 'Bark,Meow', 'Run,Slam',
#        'Run,Frying_(food)', 'Whispering,Computer_keyboard,Fart,Scissors',
#        'Gasp,Writing,Squeak,Finger_snapping,Scissors', 'Squeak,Fart',
#        'Fill_(with_liquid),Knock,Toilet_flush',
#        'Male_singing,Burping_and_eructation,Screaming,Sneeze',
#        'Hiss,Printer', 'Zipper_(clothing),Shatter,Tap',
#        'Shatter,Burping_and_eructation', 'Bark,Tick-tock',
#        'Chewing_and_mastication,Chirp_and_tweet',
#        'Applause,Female_singing', 'Tick-tock,Finger_snapping',
#        'Computer_keyboard,Drawer_open_or_close',
#        'Fill_(with_liquid),Bathtub_(filling_or_washing),Raindrop,Water_tap_and_faucet,Sink_(filling_or_washing)',
#        'Mechanical_fan,Meow', 'Computer_keyboard,Applause',
#        'Gasp,Sigh,Gurgling,Toilet_flush', 'Hi-hat,Chink_and_clink',
#        'Meow,Traffic_noise_and_roadway_noise',
#        'Car_passing_by,Race_car_and_auto_racing,Traffic_noise_and_roadway_noise',
#        'Child_speech_and_kid_speaking,Sigh',
#        'Female_speech_and_woman_speaking,Drawer_open_or_close',
#        'Strum,Scissors,Harmonica', 'Drip,Buzz',
#        'Cutlery_and_silverware,Sink_(filling_or_washing)',
#        'Cricket,Microwave_oven,Church_bell',
#        'Child_speech_and_kid_speaking,Clapping',
#        'Applause,Drawer_open_or_close',
#        'Male_singing,Finger_snapping,Clapping', 'Tap,Harmonica',
#        'Bass_drum,Harmonica',
#        'Marimba_and_xylophone,Glockenspiel,Skateboard',
#        'Walk_and_footsteps,Harmonica',
#        'Cupboard_open_or_close,Drawer_open_or_close,Clapping',
#        'Fill_(with_liquid),Water_tap_and_faucet,Drip',
#        'Gasp,Fill_(with_liquid),Drip,Sigh,Toilet_flush',
#        'Microwave_oven,Bass_guitar,Gong',
#        'Shatter,Cupboard_open_or_close,Knock', 'Skateboard,Gong',
#        'Male_singing,Female_speech_and_woman_speaking',
#        'Fill_(with_liquid),Microwave_oven', 'Drip,Finger_snapping',
#        'Cupboard_open_or_close,Dishes_and_pots_and_pans', 'Tap,Sigh',
#        'Fill_(with_liquid),Keys_jangling,Scissors',
#        'Fill_(with_liquid),Water_tap_and_faucet,Hiss,Toilet_flush',
#        'Child_speech_and_kid_speaking,Finger_snapping',
#        'Skateboard,Church_bell',
#        'Bicycle_bell,Keys_jangling,Chink_and_clink,Scissors',
#        'Writing,Burping_and_eructation,Scissors',
#        'Drip,Dishes_and_pots_and_pans,Cutlery_and_silverware',
#        'Gasp,Writing,Fart,Sneeze', 'Bicycle_bell,Chirp_and_tweet',
#        'Purr,Fart,Drawer_open_or_close', 'Applause,Slam',
#        'Zipper_(clothing),Child_speech_and_kid_speaking,Buzz',
#        'Burping_and_eructation,Dishes_and_pots_and_pans',
#        'Meow,Drawer_open_or_close',
#        'Water_tap_and_faucet,Dishes_and_pots_and_pans,Toilet_flush',
#        'Squeak,Sigh', 'Trickle_and_dribble,Gurgling',
#        'Marimba_and_xylophone,Chink_and_clink',
#        'Microwave_oven,Church_bell', 'Cutlery_and_silverware,Scissors',
#        'Zipper_(clothing),Gurgling',
#        'Fart,Accelerating_and_revving_and_vroom',
#        'Zipper_(clothing),Writing,Fart,Scissors',
#        'Writing,Whispering,Squeak', 'Computer_keyboard,Drip',
#        'Zipper_(clothing),Sneeze,Scissors', 'Gasp,Sigh,Chirp_and_tweet',
#        'Tap,Cupboard_open_or_close,Clapping,Slam'], dtype=object)

# %%
# Same as with the curated set, we'll ignore multi labeled rows for now.
# Unlike the curated set though this will drastically cut down a large portion of the data set
train = train[train['labels'].isin(test.columns[1:])]
print(len(train))
# Out:
# 16566

# %%
(19815 - 16566) / 19815 # We lose roughly 16% of our data set in order to make this simplification
# Out:
# 0.1639666919000757

# %%
test.sample(2)
# Out:
#             fname  Accelerating_and_revving_and_vroom  Accordion  \
# 790  3061e8d1.wav                                   0          0
# 14   006ea9ee.wav                                   0          0
#
#      Acoustic_guitar  Applause  Bark  Bass_drum  Bass_guitar  \
# 790                0         0     0          0            0
# 14                 0         0     0          0            0
#
#      Bathtub_(filling_or_washing)  Bicycle_bell        ...          \
# 790                             0             0        ...
# 14                              0             0        ...
#
#      Toilet_flush  Traffic_noise_and_roadway_noise  Trickle_and_dribble  \
# 790             0                                0                    0
# 14              0                                0                    0
#
#      Walk_and_footsteps  Water_tap_and_faucet  Waves_and_surf  Whispering  \
# 790                   0                     0               0           0
# 14                    0                     0               0           0
#
#      Writing  Yell  Zipper_(clothing)
# 790        0     0                  0
# 14         0     0                  0
#
# [2 rows x 81 columns]

# %%
category_group = train.groupby(['labels']).count()
category_group.columns = ['counts']
print(len(category_group))
# Out:
# 1168

# %%
# The Configuration object stores those learning parameters that are shared
# between data generators models, and training functions. Anything that is
# global as far as the training is concerned can become the part of Configuration object.

class Config(object):
    def __init__(self,
                 sampling_rate=16000,
                 audio_duration=2, 
                 n_classes=len(category_group),
                 use_mfcc=False,
                 n_folds=10,
                 learning_rate=0.0001, 
                 max_epochs=50,
                 n_mfcc=20):
        self.sampling_rate = sampling_rate
        self.audio_duration = audio_duration
        self.n_classes = n_classes
        self.use_mfcc = use_mfcc
        self.n_mfcc = n_mfcc
        self.n_folds = n_folds
        self.learning_rate = learning_rate
        self.max_epochs = max_epochs

        self.audio_length = self.sampling_rate * self.audio_duration
        if self.use_mfcc:
            self.dim = (self.n_mfcc, 1 + int(np.floor(self.audio_length/512)), 1)
        else:
            self.dim = (self.audio_length, 1)

# %%
# The DataGenerator class inherits from keras.utils.Sequence .
# It is useful for preprocessing and feeding the data to a Keras model.

# Note: Sequence are a safer way to do multiprocessing.
# This structure guarantees that the network will only train once on each
# sample per epoch which is not the case with generators.

class DataGenerator(Sequence):
    def __init__(self,
                 config,
                 data_dir,
                 list_IDs,
                 labels=None, 
                 batch_size=64,
                 preprocessing_fn=lambda x: x):
        self.config = config
        self.data_dir = data_dir
        self.list_IDs = list_IDs
        self.labels = labels
        self.batch_size = batch_size
        self.preprocessing_fn = preprocessing_fn
        self.on_epoch_end()
        self.dim = self.config.dim

    def __len__(self):
        # Once initialized with a batch_size, DataGenerator computes the number of batches in an epoch.
        # The __len__ method tells Keras how many batches to draw in each epoch.
        return int(np.ceil(len(self.list_IDs) / self.batch_size))

    def __getitem__(self, index):
        # The __getitem__ method takes an index (which is the batch number) and
        # returns a batch of the data (both X and y) after calculating the offset.
        # During test time, only X is returned.
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]
        list_IDs_temp = [self.list_IDs[k] for k in indexes]
        return self.__data_generation(list_IDs_temp)

    def on_epoch_end(self):
        # If we want to perform some action after each epoch (like shuffle the data,
        # or increase the proportion of augmented data), we can use the on_epoch_end method.
        self.indexes = np.arange(len(self.list_IDs))

    def __data_generation(self, list_IDs_temp):
        cur_batch_size = len(list_IDs_temp)
        X = np.empty((cur_batch_size, *self.dim))

        input_length = self.config.audio_length
        for i, ID in enumerate(list_IDs_temp):
            file_path = self.data_dir + ID
            
            # Read and Resample the audio
            data, _ = librosa.core.load(file_path, sr=self.config.sampling_rate, res_type='kaiser_fast')

            # Random offset / Padding
            if len(data) > input_length:
                max_offset = len(data) - input_length
                offset = np.random.randint(max_offset)
                data = data[offset:(input_length+offset)]
            else:
                if input_length > len(data):
                    max_offset = input_length - len(data)
                    offset = np.random.randint(max_offset)
                else:
                    offset = 0
                data = np.pad(data, (offset, input_length - len(data) - offset), "constant")
                
            # Normalization + Other Preprocessing
            if self.config.use_mfcc:
                data = librosa.feature.mfcc(data, sr=self.config.sampling_rate, n_mfcc=self.config.n_mfcc)
                data = np.expand_dims(data, axis=-1)
            else:
                data = self.preprocessing_fn(data)[:, np.newaxis]
            X[i,] = data

        if self.labels is not None:
            y = np.empty(cur_batch_size, dtype=int)
            for i, ID in enumerate(list_IDs_temp):
                y[i] = self.labels[ID]
            return X, to_categorical(y, num_classes=self.config.n_classes)
        else:
            return X

# %%
def get_2d_dummy_model(config):
    
    nclass = config.n_classes
    
    inp = Input(shape=(config.dim[0],config.dim[1],1))
    x = GlobalMaxPool2D()(inp)
    out = Dense(nclass, activation=softmax)(x)

    model = models.Model(inputs=inp, outputs=out)
    opt = optimizers.Adam(config.learning_rate)

    model.compile(optimizer=opt, loss=losses.categorical_crossentropy, metrics=['acc'])
    return model


def get_2d_conv_model(config):
    
    nclass = config.n_classes
    
    inp = Input(shape=(config.dim[0],config.dim[1],1))
    x = Convolution2D(32, (4,10), padding="same")(inp)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = MaxPool2D()(x)
    
    x = Convolution2D(32, (4,10), padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = MaxPool2D()(x)
    
    x = Convolution2D(32, (4,10), padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = MaxPool2D()(x)
    
    x = Convolution2D(32, (4,10), padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = MaxPool2D()(x)

    x = Flatten()(x)
    x = Dense(64)(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    out = Dense(nclass, activation=softmax)(x)

    model = models.Model(inputs=inp, outputs=out)
    opt = optimizers.Adam(config.learning_rate)

    model.compile(optimizer=opt, loss=losses.categorical_crossentropy, metrics=['acc'])
    return model

# %%
# It is important to convert raw labels to integer indices
train.head()
# Out:
#           fname                                          labels
# 0  00097e21.wav                    Bathtub_(filling_or_washing)
# 1  000b6cfb.wav                                      Motorcycle
# 2  00116cd2.wav              Marimba_and_xylophone,Glockenspiel
# 3  00127d14.wav  Water_tap_and_faucet,Sink_(filling_or_washing)
# 4  0019adae.wav                                        Raindrop

# %%
LABELS = list(train['labels'].unique())
label_idx = {label: i for i, label in enumerate(LABELS)}

train.set_index("fname", inplace=True)
test.set_index("fname", inplace=True)

train["label_idx"] = train['labels'].apply(lambda x: label_idx[x])

if not COMPLETE_RUN:
    train = train[:2000]
    test = test[:2000]

# %%
# raw labels with integer indices
train.head()
# Out:
#                                                       labels  label_idx
# fname
# 00097e21.wav                    Bathtub_(filling_or_washing)          0
# 000b6cfb.wav                                      Motorcycle          1
# 00116cd2.wav              Marimba_and_xylophone,Glockenspiel          2
# 00127d14.wav  Water_tap_and_faucet,Sink_(filling_or_washing)          3
# 0019adae.wav                                        Raindrop          4

# %%
config = Config(sampling_rate=44100, audio_duration=2, n_folds=10, 
                learning_rate=0.001, use_mfcc=True, n_mfcc=40)
if not COMPLETE_RUN:
    config = Config(sampling_rate=44100, audio_duration=2, n_folds=2, 
                    max_epochs=1, use_mfcc=True, n_mfcc=40)

# %%
def prepare_data(df, config, data_dir):
    X = np.empty(shape=(df.shape[0], config.dim[0], config.dim[1], 1))
    input_length = config.audio_length
    for i, fname in enumerate(df.index):
        file_path = data_dir + fname
        data, _ = librosa.core.load(file_path, sr=config.sampling_rate, res_type="kaiser_fast")

        # Random offset / Padding
        if len(data) > input_length:
            max_offset = len(data) - input_length
            offset = np.random.randint(max_offset)
            data = data[offset:(input_length+offset)]
        else:
            if input_length > len(data):
                max_offset = input_length - len(data)
                offset = np.random.randint(max_offset)
            else:
                offset = 0
            data = np.pad(data, (offset, input_length - len(data) - offset), "constant")

        data = librosa.feature.mfcc(data, sr=config.sampling_rate, n_mfcc=config.n_mfcc)
        data = np.expand_dims(data, axis=-1)
        X[i,] = data
    return X

# %%
# %time
X_train = prepare_data(train, config, data_path + '/train_noisy/')
X_test = prepare_data(test, config, data_path + '/test/')
y_train = to_categorical(train.label_idx.astype('str'), num_classes=config.n_classes)
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 5.48 µs

# %%
# Normalize data

mean = np.mean(X_train, axis=0)
std = np.std(X_train, axis=0)

X_train = (X_train - mean)/std
X_test = (X_test - mean)/std

# %%
# Training 2D Conv on MFCC

PREDICTION_FOLDER = "predictions_2d_conv"
if not os.path.exists(PREDICTION_FOLDER):
    os.mkdir(PREDICTION_FOLDER)
if os.path.exists('logs/' + PREDICTION_FOLDER):
    shutil.rmtree('logs/' + PREDICTION_FOLDER)

skf = StratifiedKFold(n_splits=config.n_folds)

for i, (train_split, val_split) in enumerate(skf.split(train.index, train.label_idx)):
    K.clear_session()
    X, y, X_val, y_val = X_train[train_split], y_train[train_split], X_train[val_split], y_train[val_split]
    checkpoint = ModelCheckpoint('best_%d.h5'%i, monitor='val_loss', verbose=1, save_best_only=True)
    early = EarlyStopping(monitor="val_loss", mode="min", patience=5)
    tb = TensorBoard(log_dir='./logs/' + PREDICTION_FOLDER + '/fold_%i'%i, write_graph=True)
    callbacks_list = [checkpoint, early, tb]
    print("#"*50)
    print("Fold: ", i)
    model = get_2d_conv_model(config)
    history = model.fit(X, y, validation_data=(X_val, y_val), callbacks=callbacks_list, 
                        batch_size=64, epochs=config.max_epochs)
    model.load_weights('best_%d.h5'%i)

    # Save train predictions
    predictions = model.predict(X_train, batch_size=64, verbose=1)
    np.save(PREDICTION_FOLDER + "/train_predictions_%d.npy"%i, predictions)

    # Save test predictions
    predictions = model.predict(X_test, batch_size=64, verbose=1)
    np.save(PREDICTION_FOLDER + "/test_predictions_%d.npy"%i, predictions)

    # Make a submission file
    top_3 = np.array(LABELS)[np.argsort(-predictions, axis=1)[:, :3]]
    predicted_labels = [' '.join(list(x)) for x in top_3]
    test['label'] = predicted_labels
    test[['label']].to_csv(PREDICTION_FOLDER + "/predictions_%d.csv"%i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-32d90729dfda> in <module>()
#       2
#       3 PREDICTION_FOLDER = "predictions_2d_conv"
# ----> 4 if not os.path.exists(PREDICTION_FOLDER):
#       5     os.mkdir(PREDICTION_FOLDER)
#       6 if os.path.exists('logs/' + PREDICTION_FOLDER):
#
# NameError: name 'os' is not defined

# %%
# Ensembling 2D Conv Predictions¶

pred_list = []
for i in range(config.n_folds):
    pred_list.append(np.load("./predictions_2d_conv/test_predictions_%d.npy"%i))
prediction = np.ones_like(pred_list[0])
for pred in pred_list:
    prediction = prediction*pred
prediction = prediction**(1./len(pred_list))
# Make a submission file
top_3 = np.array(LABELS)[np.argsort(-prediction, axis=1)[:, :3]]
predicted_labels = [' '.join(list(x)) for x in top_3]
test = pd.read_csv(data_path + '/sample_submission.csv')
test['label'] = predicted_labels
test[['fname', 'label']].to_csv("2d_conv_ensembled_submission.csv", index=False)
